# %% [markdown]
# This notebook contains code that was used at some point to format XES event logs into CSV, and split them into 80-20 training and test sets.

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import pm4py
import plotly.express as px

# %%
def time_spread(df, df_test):

  combined_df = pd.DataFrame({
      'TRAIN': df['DATAEV'],
      'TEST': df_test['DATAEV']
  })

  fig = px.histogram(combined_df, x=["TRAIN", "TEST"])
  fig.update_layout(bargap=0.2, barmode='overlay')
  fig.show()

# %%
def my_train_test_split(df):
  """
  Splits the dataset into a train and a test,
  finding a cutoff to approximately
  have a 80-20 split,
  first trying to split on a certain date
  """
  ratios = {}
  n = len(df)
  for i in np.arange(0.025, 1., 0.025):
      cutoff = n*i
      t = pd.to_datetime(df.iloc[int(cutoff)].DATAEV).round('d')
      g = df.groupby("NUMPRO").DATAEV.max()
      try:
        ind = g[pd.to_datetime(g) <= t].keys()[-1] # We want cases in the train set to have timestamps smaller than t
      except:
        continue
      df_train = df[df.NUMPRO <= ind]
      df_test = df[df.NUMPRO > ind]
      ratios[i] = len(df_train)/len(df)
      # print(i, ratios[i])

  final_percentage = min(ratios.values(), key=lambda x: abs(x-0.8))
  final_cutoff = n*final_percentage
  t = pd.to_datetime(df.iloc[int(final_cutoff)].DATAEV).round('d')
  g = df.groupby("NUMPRO").DATAEV.max()
  ind = g[pd.to_datetime(g) <= t].keys()[-1]

  df_train = df[df.NUMPRO < ind].reset_index(drop=True)
  df_test = df[df.NUMPRO >= ind].reset_index(drop=True)

  final_split = len(df_train)/len(df) # We want df_train to be approximately 80% as big as df

  if (0.7 < final_split < 0.9):
    print("Cut-off date:", t.strftime('%Y-%m-%d'))
    return df_train, df_test

  else: # too much overlap to have a nice temporal split
    cases_ordered = df.groupby("NUMPRO").DATAEV.min().sort_values().keys() # cases numbers ordered by earliest event
    cutoff = int(0.8*len(cases_ordered))
    df_train = df[df.NUMPRO.isin(cases_ordered[:cutoff])].reset_index(drop=True)
    df_test = df[df.NUMPRO.isin(cases_ordered[cutoff:])].reset_index(drop=True)

  return df_train, df_test

# %% [markdown]
# Train-Test split at ~80%

# %% [markdown]
# # BPIC12

# %%
dataset = "BPIC12"

# %% [markdown]
# https://data.4tu.nl/articles/dataset/BPI_Challenge_2012/12689204

# %%
df = pm4py.read_xes('BPI_Challenge_2012.xes')
df
# Out:
# parsing log, completed traces ::   0%|          | 0/13087 [00:00<?, ?it/s]
#        org:resource lifecycle:transition            concept:name  \
# 0               112             COMPLETE             A_SUBMITTED
# 1               112             COMPLETE       A_PARTLYSUBMITTED
# 2               112             COMPLETE           A_PREACCEPTED
# 3               112             SCHEDULE  W_Completeren aanvraag
# 4               NaN                START  W_Completeren aanvraag
# ...             ...                  ...                     ...
# 262195          112             COMPLETE       A_PARTLYSUBMITTED
# 262196          112             SCHEDULE      W_Afhandelen leads
# 262197        11169                START      W_Afhandelen leads
# 262198        11169             COMPLETE              A_DECLINED
# 262199        11169             COMPLETE      W_Afhandelen leads
#
#                          time:timestamp                    case:REG_DATE  \
# 0      2011-10-01 00:38:44.546000+00:00 2011-10-01 00:38:44.546000+00:00
# 1      2011-10-01 00:38:44.880000+00:00 2011-10-01 00:38:44.546000+00:00
# 2      2011-10-01 00:39:37.906000+00:00 2011-10-01 00:38:44.546000+00:00
# 3      2011-10-01 00:39:38.875000+00:00 2011-10-01 00:38:44.546000+00:00
# 4      2011-10-01 11:36:46.437000+00:00 2011-10-01 00:38:44.546000+00:00
# ...                                 ...                              ...
# 262195 2012-02-29 23:51:17.423000+00:00 2012-02-29 23:51:16.799000+00:00
# 262196 2012-02-29 23:52:01.287000+00:00 2012-02-29 23:51:16.799000+00:00
# 262197 2012-03-01 09:26:46.736000+00:00 2012-02-29 23:51:16.799000+00:00
# 262198 2012-03-01 09:27:37.118000+00:00 2012-02-29 23:51:16.799000+00:00
# 262199 2012-03-01 09:27:41.325000+00:00 2012-02-29 23:51:16.799000+00:00
#
#        case:concept:name case:AMOUNT_REQ
# 0                 173688           20000
# 1                 173688           20000
# 2                 173688           20000
# 3                 173688           20000
# 4                 173688           20000
# ...                  ...             ...
# 262195            214376           15000
# 262196            214376           15000
# 262197            214376           15000
# 262198            214376           15000
# 262199            214376           15000
#
# [262200 rows x 7 columns]

# %%
df = df[["case:concept:name", "concept:name", "time:timestamp", "org:resource"]].rename(columns={"case:concept:name": "NUMPRO", "concept:name": "CCDOEV", "time:timestamp": "DATAEV", "org:resource": "NUMGIU"})
df.DATAEV = pd.to_datetime(df.DATAEV).dt.strftime('%Y-%m-%d %H:%M:%S')
cases_ordered = df.groupby("NUMPRO").DATAEV.min().sort_values().keys() # cases numbers ordered by earliest event
df.NUMPRO = pd.Categorical(df.NUMPRO, categories = list(cases_ordered)) # Order cases by earliest event
df = df.sort_values(by = ["NUMPRO","DATAEV"])
df.NUMPRO = df.NUMPRO.astype(int)
df
# Out:
#         NUMPRO                  CCDOEV               DATAEV NUMGIU
# 0       173688             A_SUBMITTED  2011-10-01 00:38:44    112
# 1       173688       A_PARTLYSUBMITTED  2011-10-01 00:38:44    112
# 2       173688           A_PREACCEPTED  2011-10-01 00:39:37    112
# 3       173688  W_Completeren aanvraag  2011-10-01 00:39:38    112
# 4       173688  W_Completeren aanvraag  2011-10-01 11:36:46    NaN
# ...        ...                     ...                  ...    ...
# 262195  214376       A_PARTLYSUBMITTED  2012-02-29 23:51:17    112
# 262196  214376      W_Afhandelen leads  2012-02-29 23:52:01    112
# 262197  214376      W_Afhandelen leads  2012-03-01 09:26:46  11169
# 262198  214376              A_DECLINED  2012-03-01 09:27:37  11169
# 262199  214376      W_Afhandelen leads  2012-03-01 09:27:41  11169
#
# [262200 rows x 4 columns]

# %%
df_train, df_test = my_train_test_split(df)
# Out:
# Cut-off date: 2012-02-02

# %%
df_train
# Out:
#         NUMPRO                  CCDOEV               DATAEV NUMGIU
# 0       173688             A_SUBMITTED  2011-10-01 00:38:44    112
# 1       173688       A_PARTLYSUBMITTED  2011-10-01 00:38:44    112
# 2       173688           A_PREACCEPTED  2011-10-01 00:39:37    112
# 3       173688  W_Completeren aanvraag  2011-10-01 00:39:38    112
# 4       173688  W_Completeren aanvraag  2011-10-01 11:36:46    NaN
# ...        ...                     ...                  ...    ...
# 210410  205782              O_ACCEPTED  2012-03-01 11:47:41  10809
# 210411  205782              A_APPROVED  2012-03-01 11:47:41  10809
# 210412  205782            A_REGISTERED  2012-03-01 11:47:41  10809
# 210413  205782             A_ACTIVATED  2012-03-01 11:47:41  10809
# 210414  205782    W_Valideren aanvraag  2012-03-01 11:47:50  10809
#
# [210415 rows x 4 columns]

# %%
df_test
# Out:
#        NUMPRO              CCDOEV               DATAEV NUMGIU
# 0      205785         A_SUBMITTED  2012-02-01 22:35:33    112
# 1      205785   A_PARTLYSUBMITTED  2012-02-01 22:35:35    112
# 2      205785          A_DECLINED  2012-02-01 22:36:20    112
# 3      205788         A_SUBMITTED  2012-02-01 23:06:24    112
# 4      205788   A_PARTLYSUBMITTED  2012-02-01 23:06:25    112
# ...       ...                 ...                  ...    ...
# 51780  214376   A_PARTLYSUBMITTED  2012-02-29 23:51:17    112
# 51781  214376  W_Afhandelen leads  2012-02-29 23:52:01    112
# 51782  214376  W_Afhandelen leads  2012-03-01 09:26:46  11169
# 51783  214376          A_DECLINED  2012-03-01 09:27:37  11169
# 51784  214376  W_Afhandelen leads  2012-03-01 09:27:41  11169
#
# [51785 rows x 4 columns]

# %%
time_spread(df_train, df_test)

# %%
df_train.to_csv(f'./{dataset}/{dataset}/{dataset}_prepared/{dataset}-TRAIN-CLEAN.csv', index=False)
df_test.to_csv(f'./{dataset}/{dataset}/{dataset}-TEST-CLEAN.csv', index=False)

# %% [markdown]
# # BPIC17

# %%
dataset = "BPIC17"

# %% [markdown]
# https://data.4tu.nl/articles/dataset/BPI_Challenge_2017/12696884

# %%
df = pm4py.read_xes('BPI Challenge 2017.xes')
df
# Out:
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]
#               Action org:resource            concept:name  EventOrigin  \
# 0            Created       User_1    A_Create Application  Application
# 1        statechange       User_1             A_Submitted  Application
# 2            Created       User_1          W_Handle leads     Workflow
# 3            Deleted       User_1          W_Handle leads     Workflow
# 4            Created       User_1  W_Complete application     Workflow
# ...              ...          ...                     ...          ...
# 1202262      Deleted       User_1     W_Call after offers     Workflow
# 1202263      Created       User_1     W_Call after offers     Workflow
# 1202264  statechange      User_28             A_Cancelled  Application
# 1202265  statechange      User_28             O_Cancelled        Offer
# 1202266      Deleted      User_28     W_Call after offers     Workflow
#
#                        EventID lifecycle:transition  \
# 0        Application_652823628             complete
# 1         ApplState_1582051990             complete
# 2          Workitem_1298499574             schedule
# 3          Workitem_1673366067             withdraw
# 4          Workitem_1493664571             schedule
# ...                        ...                  ...
# 1202262    Workitem_1817549786            ate_abort
# 1202263     Workitem_363876066             schedule
# 1202264   ApplState_1869071797             complete
# 1202265   OfferState_420066181             complete
# 1202266    Workitem_1934044935             withdraw
#
#                           time:timestamp           case:LoanGoal  \
# 0       2016-01-01 09:51:15.304000+00:00  Existing loan takeover
# 1       2016-01-01 09:51:15.352000+00:00  Existing loan takeover
# 2       2016-01-01 09:51:15.774000+00:00  Existing loan takeover
# 3       2016-01-01 09:52:36.392000+00:00  Existing loan takeover
# 4       2016-01-01 09:52:36.403000+00:00  Existing loan takeover
# ...                                  ...                     ...
# 1202262 2017-01-06 06:33:02.212000+00:00        Home improvement
# 1202263 2017-01-06 06:33:02.221000+00:00        Home improvement
# 1202264 2017-01-16 09:51:21.114000+00:00        Home improvement
# 1202265 2017-01-16 09:51:21.139000+00:00        Home improvement
# 1202266 2017-01-16 09:51:21.146000+00:00        Home improvement
#
#         case:ApplicationType       case:concept:name  case:RequestedAmount  \
# 0                 New credit   Application_652823628               20000.0
# 1                 New credit   Application_652823628               20000.0
# 2                 New credit   Application_652823628               20000.0
# 3                 New credit   Application_652823628               20000.0
# 4                 New credit   Application_652823628               20000.0
# ...                      ...                     ...                   ...
# 1202262           New credit  Application_1350494635               20000.0
# 1202263           New credit  Application_1350494635               20000.0
# 1202264           New credit  Application_1350494635               20000.0
# 1202265           New credit  Application_1350494635               20000.0
# 1202266           New credit  Application_1350494635               20000.0
#
#          FirstWithdrawalAmount  NumberOfTerms Accepted  MonthlyCost Selected  \
# 0                          NaN            NaN      NaN          NaN      NaN
# 1                          NaN            NaN      NaN          NaN      NaN
# 2                          NaN            NaN      NaN          NaN      NaN
# 3                          NaN            NaN      NaN          NaN      NaN
# 4                          NaN            NaN      NaN          NaN      NaN
# ...                        ...            ...      ...          ...      ...
# 1202262                    NaN            NaN      NaN          NaN      NaN
# 1202263                    NaN            NaN      NaN          NaN      NaN
# 1202264                    NaN            NaN      NaN          NaN      NaN
# 1202265                    NaN            NaN      NaN          NaN      NaN
# 1202266                    NaN            NaN      NaN          NaN      NaN
#
#          CreditScore  OfferedAmount           OfferID
# 0                NaN            NaN               NaN
# 1                NaN            NaN               NaN
# 2                NaN            NaN               NaN
# 3                NaN            NaN               NaN
# 4                NaN            NaN               NaN
# ...              ...            ...               ...
# 1202262          NaN            NaN               NaN
# 1202263          NaN            NaN               NaN
# 1202264          NaN            NaN               NaN
# 1202265          NaN            NaN  Offer_1580299144
# 1202266          NaN            NaN               NaN
#
# [1202267 rows x 19 columns]

# %%
df = df[["case:concept:name", "concept:name", "time:timestamp", "org:resource"]].rename(columns={"case:concept:name": "NUMPRO", "concept:name": "CCDOEV", "time:timestamp": "DATAEV", "org:resource": "NUMGIU"})
df.DATAEV = pd.to_datetime(df.DATAEV).dt.strftime('%Y-%m-%d %H:%M:%S')
cases_ordered = df.groupby("NUMPRO").DATAEV.min().sort_values().keys() # cases numbers ordered by earliest event
df.NUMPRO = pd.Categorical(df.NUMPRO, categories = list(cases_ordered)) # Order cases by earliest event
df = df.sort_values(by = ["NUMPRO","DATAEV"])
df.NUMPRO = df.NUMPRO.str.split('_').str[-1].astype(int)
df
# Out:
#              NUMPRO                  CCDOEV               DATAEV   NUMGIU
# 0         652823628    A_Create Application  2016-01-01 09:51:15   User_1
# 1         652823628             A_Submitted  2016-01-01 09:51:15   User_1
# 2         652823628          W_Handle leads  2016-01-01 09:51:15   User_1
# 3         652823628          W_Handle leads  2016-01-01 09:52:36   User_1
# 4         652823628  W_Complete application  2016-01-01 09:52:36   User_1
# ...             ...                     ...                  ...      ...
# 1202262  1350494635     W_Call after offers  2017-01-06 06:33:02   User_1
# 1202263  1350494635     W_Call after offers  2017-01-06 06:33:02   User_1
# 1202264  1350494635             A_Cancelled  2017-01-16 09:51:21  User_28
# 1202265  1350494635             O_Cancelled  2017-01-16 09:51:21  User_28
# 1202266  1350494635     W_Call after offers  2017-01-16 09:51:21  User_28
#
# [1202267 rows x 4 columns]

# %%
# We cannot split BPIC17 80-20 without significant overlap between the temporal frames of train and test
# So no cutoff date in particular, and train and test cover similar periods
# (We could still cut at some date, but most cases would then be cut in two between the two sets)
df_train, df_test = my_train_test_split(df)

# %%
df_train
# Out:
#             NUMPRO                  CCDOEV               DATAEV  NUMGIU
# 0        652823628    A_Create Application  2016-01-01 09:51:15  User_1
# 1        652823628             A_Submitted  2016-01-01 09:51:15  User_1
# 2        652823628          W_Handle leads  2016-01-01 09:51:15  User_1
# 3        652823628          W_Handle leads  2016-01-01 09:52:36  User_1
# 4        652823628  W_Complete application  2016-01-01 09:52:36  User_1
# ...            ...                     ...                  ...     ...
# 961203  1109722425     W_Call after offers  2016-10-25 06:24:39  User_5
# 961204  1109722425     W_Call after offers  2016-10-25 06:25:18  User_5
# 961205  1109722425             A_Cancelled  2016-11-21 07:00:34  User_1
# 961206  1109722425             O_Cancelled  2016-11-21 07:00:34  User_1
# 961207  1109722425     W_Call after offers  2016-11-21 07:00:34  User_1
#
# [961208 rows x 4 columns]

# %%
df_test
# Out:
#             NUMPRO                CCDOEV               DATAEV   NUMGIU
# 0        424064154  A_Create Application  2016-10-18 23:42:39   User_1
# 1        424064154           A_Submitted  2016-10-18 23:42:40   User_1
# 2        424064154        W_Handle leads  2016-10-18 23:42:40   User_1
# 3        424064154        W_Handle leads  2016-10-19 05:54:43  User_26
# 4        424064154        W_Handle leads  2016-10-19 05:56:36  User_26
# ...            ...                   ...                  ...      ...
# 241054  1350494635   W_Call after offers  2017-01-06 06:33:02   User_1
# 241055  1350494635   W_Call after offers  2017-01-06 06:33:02   User_1
# 241056  1350494635           A_Cancelled  2017-01-16 09:51:21  User_28
# 241057  1350494635           O_Cancelled  2017-01-16 09:51:21  User_28
# 241058  1350494635   W_Call after offers  2017-01-16 09:51:21  User_28
#
# [241059 rows x 4 columns]

# %%
time_spread(df_train, df_test)

# %%
df_train.to_csv(f'./{dataset}/{dataset}/{dataset}_prepared/{dataset}-TRAIN-CLEAN.csv', index=False)
df_test.to_csv(f'./{dataset}/{dataset}/{dataset}-TEST-CLEAN.csv', index=False)

# %% [markdown]
# # BPIC20

# %%
dataset = "BPIC20"

# %% [markdown]
# https://data.4tu.nl/collections/_/5065541/1

# %% [markdown]
# ## DomesticDeclarations

# %%
subset = "DomesticDeclarations"

# %%
df = pm4py.read_xes('DomesticDeclarations.xes')
df
# Out:
# parsing log, completed traces ::   0%|          | 0/10500 [00:00<?, ?it/s]
#                              id  org:resource  \
# 0               st_step 86794_0  STAFF MEMBER
# 1               st_step 86793_0  STAFF MEMBER
# 2       dd_declaration 86791_19        SYSTEM
# 3       dd_declaration 86791_20        SYSTEM
# 4               st_step 86798_0  STAFF MEMBER
# ...                         ...           ...
# 56432          st_step 138363_0  STAFF MEMBER
# 56433          st_step 138361_0  STAFF MEMBER
# 56434          st_step 138362_0  STAFF MEMBER
# 56435  dd_declaration 138359_19        SYSTEM
# 56436  dd_declaration 138359_20        SYSTEM
#
#                                    concept:name            time:timestamp  \
# 0             Declaration SUBMITTED by EMPLOYEE 2017-01-09 09:49:50+00:00
# 1      Declaration FINAL_APPROVED by SUPERVISOR 2017-01-09 11:27:48+00:00
# 2                               Request Payment 2017-01-10 09:34:44+00:00
# 3                               Payment Handled 2017-01-12 17:31:22+00:00
# 4             Declaration SUBMITTED by EMPLOYEE 2017-01-09 10:26:14+00:00
# ...                                         ...                       ...
# 56432         Declaration SUBMITTED by EMPLOYEE 2018-12-29 17:50:14+00:00
# 56433    Declaration APPROVED by ADMINISTRATION 2018-12-29 17:56:13+00:00
# 56434  Declaration FINAL_APPROVED by SUPERVISOR 2019-01-03 08:55:52+00:00
# 56435                           Request Payment 2019-01-08 08:20:28+00:00
# 56436                           Payment Handled 2019-01-10 17:31:08+00:00
#
#              org:role             case:id   case:concept:name  \
# 0            EMPLOYEE   declaration 86791   declaration 86791
# 1          SUPERVISOR   declaration 86791   declaration 86791
# 2           UNDEFINED   declaration 86791   declaration 86791
# 3           UNDEFINED   declaration 86791   declaration 86791
# 4            EMPLOYEE   declaration 86795   declaration 86795
# ...               ...                 ...                 ...
# 56432        EMPLOYEE  declaration 138359  declaration 138359
# 56433  ADMINISTRATION  declaration 138359  declaration 138359
# 56434      SUPERVISOR  declaration 138359  declaration 138359
# 56435       UNDEFINED  declaration 138359  declaration 138359
# 56436       UNDEFINED  declaration 138359  declaration 138359
#
#       case:BudgetNumber     case:DeclarationNumber  case:Amount
# 0          budget 86566   declaration number 86792    26.851205
# 1          budget 86566   declaration number 86792    26.851205
# 2          budget 86566   declaration number 86792    26.851205
# 3          budget 86566   declaration number 86792    26.851205
# 4          budget 86566   declaration number 86796   182.464172
# ...                 ...                        ...          ...
# 56432      budget 86566  declaration number 138360   190.404576
# 56433      budget 86566  declaration number 138360   190.404576
# 56434      budget 86566  declaration number 138360   190.404576
# 56435      budget 86566  declaration number 138360   190.404576
# 56436      budget 86566  declaration number 138360   190.404576
#
# [56437 rows x 10 columns]

# %%
df = df[["case:concept:name", "concept:name", "time:timestamp", "org:resource"]].rename(columns={"case:concept:name": "NUMPRO", "concept:name": "CCDOEV", "time:timestamp": "DATAEV", "org:resource": "NUMGIU"})
df.DATAEV = pd.to_datetime(df.DATAEV).dt.strftime('%Y-%m-%d %H:%M:%S')
cases_ordered = df.groupby("NUMPRO").DATAEV.min().sort_values().keys() # cases numbers ordered by earliest event
df.NUMPRO = pd.Categorical(df.NUMPRO, categories = list(cases_ordered)) # Order cases by earliest event
df = df.sort_values(by = ["NUMPRO","DATAEV"])
df.NUMPRO = df.NUMPRO.str.split().str[-1].astype(int)
df
# Out:
#        NUMPRO                                    CCDOEV               DATAEV  \
# 0       86791         Declaration SUBMITTED by EMPLOYEE  2017-01-09 09:49:50
# 1       86791  Declaration FINAL_APPROVED by SUPERVISOR  2017-01-09 11:27:48
# 2       86791                           Request Payment  2017-01-10 09:34:44
# 3       86791                           Payment Handled  2017-01-12 17:31:22
# 4       86795         Declaration SUBMITTED by EMPLOYEE  2017-01-09 10:26:14
# ...       ...                                       ...                  ...
# 56432  138359         Declaration SUBMITTED by EMPLOYEE  2018-12-29 17:50:14
# 56433  138359    Declaration APPROVED by ADMINISTRATION  2018-12-29 17:56:13
# 56434  138359  Declaration FINAL_APPROVED by SUPERVISOR  2019-01-03 08:55:52
# 56435  138359                           Request Payment  2019-01-08 08:20:28
# 56436  138359                           Payment Handled  2019-01-10 17:31:08
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2            SYSTEM
# 3            SYSTEM
# 4      STAFF MEMBER
# ...             ...
# 56432  STAFF MEMBER
# 56433  STAFF MEMBER
# 56434  STAFF MEMBER
# 56435        SYSTEM
# 56436        SYSTEM
#
# [56437 rows x 4 columns]

# %%
df_train, df_test = my_train_test_split(df)

# %%
df_train
# Out:
#        NUMPRO                                    CCDOEV               DATAEV  \
# 0       86791         Declaration SUBMITTED by EMPLOYEE  2017-01-09 09:49:50
# 1       86791  Declaration FINAL_APPROVED by SUPERVISOR  2017-01-09 11:27:48
# 2       86791                           Request Payment  2017-01-10 09:34:44
# 3       86791                           Payment Handled  2017-01-12 17:31:22
# 4       86795         Declaration SUBMITTED by EMPLOYEE  2017-01-09 10:26:14
# ...       ...                                       ...                  ...
# 44756  136625         Declaration SUBMITTED by EMPLOYEE  2018-10-11 21:31:29
# 44757  136625    Declaration APPROVED by ADMINISTRATION  2018-10-11 21:36:07
# 44758  136625  Declaration FINAL_APPROVED by SUPERVISOR  2018-10-15 14:15:04
# 44759  136625                           Request Payment  2018-10-15 15:42:36
# 44760  136625                           Payment Handled  2018-10-18 17:31:16
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2            SYSTEM
# 3            SYSTEM
# 4      STAFF MEMBER
# ...             ...
# 44756  STAFF MEMBER
# 44757  STAFF MEMBER
# 44758  STAFF MEMBER
# 44759        SYSTEM
# 44760        SYSTEM
#
# [44761 rows x 4 columns]

# %%
df_test
# Out:
#        NUMPRO                                    CCDOEV               DATAEV  \
# 0      136630         Declaration SUBMITTED by EMPLOYEE  2018-10-11 21:44:58
# 1      136630    Declaration APPROVED by ADMINISTRATION  2018-10-11 21:48:56
# 2      136630  Declaration FINAL_APPROVED by SUPERVISOR  2018-10-18 17:02:47
# 3      136630                           Request Payment  2018-10-22 08:46:59
# 4      136630                           Payment Handled  2018-10-25 17:31:41
# ...       ...                                       ...                  ...
# 11671  138359         Declaration SUBMITTED by EMPLOYEE  2018-12-29 17:50:14
# 11672  138359    Declaration APPROVED by ADMINISTRATION  2018-12-29 17:56:13
# 11673  138359  Declaration FINAL_APPROVED by SUPERVISOR  2019-01-03 08:55:52
# 11674  138359                           Request Payment  2019-01-08 08:20:28
# 11675  138359                           Payment Handled  2019-01-10 17:31:08
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2      STAFF MEMBER
# 3            SYSTEM
# 4            SYSTEM
# ...             ...
# 11671  STAFF MEMBER
# 11672  STAFF MEMBER
# 11673  STAFF MEMBER
# 11674        SYSTEM
# 11675        SYSTEM
#
# [11676 rows x 4 columns]

# %%
df_train.dtypes
# Out:
# NUMPRO     int32
# CCDOEV    object
# DATAEV    object
# NUMGIU    object
# dtype: object

# %%
time_spread(df_train, df_test)

# %%
df_train.to_csv(f'./{dataset}/{subset}/{subset}_prepared/{subset}-TRAIN-CLEAN.csv', index=False)
df_test.to_csv(f'./{dataset}/{subset}/{subset}-TEST-CLEAN.csv', index=False)

# %% [markdown]
# ## InternationalDeclarations

# %%
subset = "InternationalDeclarations"

# %%
df = pm4py.read_xes('InternationalDeclarations.xes')
df
# Out:
# parsing log, completed traces ::   0%|          | 0/6449 [00:00<?, ?it/s]
#                              id  org:resource  \
# 0      rv_travel permit 76455_6  STAFF MEMBER
# 1      rv_travel permit 76455_7  STAFF MEMBER
# 2               st_step 76459_0  STAFF MEMBER
# 3               st_step 76460_0  STAFF MEMBER
# 4               st_step 76461_0  STAFF MEMBER
# ...                         ...           ...
# 72146           st_step 13239_0  STAFF MEMBER
# 72147           st_step 13241_0  STAFF MEMBER
# 72148           st_step 13240_0  STAFF MEMBER
# 72149  rv_travel permit 13226_6  STAFF MEMBER
# 72150  rv_travel permit 13226_7  STAFF MEMBER
#
#                                  concept:name            time:timestamp  \
# 0                                  Start trip 2016-10-05 00:00:00+00:00
# 1                                    End trip 2016-10-05 00:00:00+00:00
# 2                Permit SUBMITTED by EMPLOYEE 2017-04-06 13:32:10+00:00
# 3         Permit FINAL_APPROVED by SUPERVISOR 2017-04-06 13:32:28+00:00
# 4           Declaration SUBMITTED by EMPLOYEE 2017-04-07 13:38:14+00:00
# ...                                       ...                       ...
# 72146       Declaration SUBMITTED by EMPLOYEE 2018-12-18 15:06:50+00:00
# 72147  Declaration REJECTED by ADMINISTRATION 2018-12-18 15:06:57+00:00
# 72148        Declaration REJECTED by EMPLOYEE 2018-12-19 14:05:36+00:00
# 72149                              Start trip 2019-02-19 00:00:00+00:00
# 72150                                End trip 2019-02-24 00:00:00+00:00
#
#              org:role case:Permit travel permit number  \
# 0            EMPLOYEE       travel permit number 76456
# 1            EMPLOYEE       travel permit number 76456
# 2            EMPLOYEE       travel permit number 76456
# 3          SUPERVISOR       travel permit number 76456
# 4            EMPLOYEE       travel permit number 76456
# ...               ...                              ...
# 72146        EMPLOYEE       travel permit number 13227
# 72147  ADMINISTRATION       travel permit number 13227
# 72148        EMPLOYEE       travel permit number 13227
# 72149        EMPLOYEE       travel permit number 13227
# 72150        EMPLOYEE       travel permit number 13227
#
#          case:DeclarationNumber  case:Amount  case:RequestedAmount  \
# 0      declaration number 76458    39.664561             39.664561
# 1      declaration number 76458    39.664561             39.664561
# 2      declaration number 76458    39.664561             39.664561
# 3      declaration number 76458    39.664561             39.664561
# 4      declaration number 76458    39.664561             39.664561
# ...                         ...          ...                   ...
# 72146                   UNKNOWN     0.000000              0.000000
# 72147                   UNKNOWN     0.000000              0.000000
# 72148                   UNKNOWN     0.000000              0.000000
# 72149                   UNKNOWN     0.000000              0.000000
# 72150                   UNKNOWN     0.000000              0.000000
#
#       case:Permit TaskNumber  ...  case:concept:name  \
# 0                    UNKNOWN  ...  declaration 76457
# 1                    UNKNOWN  ...  declaration 76457
# 2                    UNKNOWN  ...  declaration 76457
# 3                    UNKNOWN  ...  declaration 76457
# 4                    UNKNOWN  ...  declaration 76457
# ...                      ...  ...                ...
# 72146               task 427  ...  declaration 13232
# 72147               task 427  ...  declaration 13232
# 72148               task 427  ...  declaration 13232
# 72149               task 427  ...  declaration 13232
# 72150               task 427  ...  declaration 13232
#
#        case:Permit OrganizationalEntity   case:travel permit number  \
# 0             organizational unit 65458  travel permit number 76456
# 1             organizational unit 65458  travel permit number 76456
# 2             organizational unit 65458  travel permit number 76456
# 3             organizational unit 65458  travel permit number 76456
# 4             organizational unit 65458  travel permit number 76456
# ...                                 ...                         ...
# 72146         organizational unit 65455  travel permit number 13227
# 72147         organizational unit 65455  travel permit number 13227
# 72148         organizational unit 65455  travel permit number 13227
# 72149         organizational unit 65455  travel permit number 13227
# 72150         organizational unit 65455  travel permit number 13227
#
#       case:Permit RequestedBudget            case:id       case:Permit ID  \
# 0                       41.613445  declaration 76457  travel permit 76455
# 1                       41.613445  declaration 76457  travel permit 76455
# 2                       41.613445  declaration 76457  travel permit 76455
# 3                       41.613445  declaration 76457  travel permit 76455
# 4                       41.613445  declaration 76457  travel permit 76455
# ...                           ...                ...                  ...
# 72146                 1727.559756  declaration 13232  travel permit 13226
# 72147                 1727.559756  declaration 13232  travel permit 13226
# 72148                 1727.559756  declaration 13232  travel permit 13226
# 72149                 1727.559756  declaration 13232  travel permit 13226
# 72150                 1727.559756  declaration 13232  travel permit 13226
#
#             case:Permit id case:BudgetNumber case:Permit ActivityNumber  \
# 0      travel permit 76455     budget 144133             activity 46005
# 1      travel permit 76455     budget 144133             activity 46005
# 2      travel permit 76455     budget 144133             activity 46005
# 3      travel permit 76455     budget 144133             activity 46005
# 4      travel permit 76455     budget 144133             activity 46005
# ...                    ...               ...                        ...
# 72146  travel permit 13226     budget 147449                    UNKNOWN
# 72147  travel permit 13226     budget 147449                    UNKNOWN
# 72148  travel permit 13226     budget 147449                    UNKNOWN
# 72149  travel permit 13226     budget 147449                    UNKNOWN
# 72150  travel permit 13226     budget 147449                    UNKNOWN
#
#       case:AdjustedAmount
# 0               39.664561
# 1               39.664561
# 2               39.664561
# 3               39.664561
# 4               39.664561
# ...                   ...
# 72146            0.000000
# 72147            0.000000
# 72148            0.000000
# 72149            0.000000
# 72150            0.000000
#
# [72151 rows x 23 columns]

# %%
df = df[["case:concept:name", "concept:name", "time:timestamp", "org:resource"]].rename(columns={"case:concept:name": "NUMPRO", "concept:name": "CCDOEV", "time:timestamp": "DATAEV", "org:resource": "NUMGIU"})
df.DATAEV = pd.to_datetime(df.DATAEV).dt.strftime('%Y-%m-%d %H:%M:%S')
cases_ordered = df.groupby("NUMPRO").DATAEV.min().sort_values().keys() # cases numbers ordered by earliest event
df.NUMPRO = pd.Categorical(df.NUMPRO, categories = list(cases_ordered)) # Order cases by earliest event
df = df.sort_values(by = ["NUMPRO","DATAEV"])
df.NUMPRO = df.NUMPRO.str.split().str[-1].astype(int)
df
# Out:
#        NUMPRO                                  CCDOEV               DATAEV  \
# 0       76457                              Start trip  2016-10-05 00:00:00
# 1       76457                                End trip  2016-10-05 00:00:00
# 2       76457            Permit SUBMITTED by EMPLOYEE  2017-04-06 13:32:10
# 3       76457     Permit FINAL_APPROVED by SUPERVISOR  2017-04-06 13:32:28
# 4       76457       Declaration SUBMITTED by EMPLOYEE  2017-04-07 13:38:14
# ...       ...                                     ...                  ...
# 72146   13232       Declaration SUBMITTED by EMPLOYEE  2018-12-18 15:06:50
# 72147   13232  Declaration REJECTED by ADMINISTRATION  2018-12-18 15:06:57
# 72148   13232        Declaration REJECTED by EMPLOYEE  2018-12-19 14:05:36
# 72149   13232                              Start trip  2019-02-19 00:00:00
# 72150   13232                                End trip  2019-02-24 00:00:00
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2      STAFF MEMBER
# 3      STAFF MEMBER
# 4      STAFF MEMBER
# ...             ...
# 72146  STAFF MEMBER
# 72147  STAFF MEMBER
# 72148  STAFF MEMBER
# 72149  STAFF MEMBER
# 72150  STAFF MEMBER
#
# [72151 rows x 4 columns]

# %%
df_train, df_test = my_train_test_split(df)

# %%
df_train
# Out:
#        NUMPRO                                    CCDOEV               DATAEV  \
# 0       76457                                Start trip  2016-10-05 00:00:00
# 1       76457                                  End trip  2016-10-05 00:00:00
# 2       76457              Permit SUBMITTED by EMPLOYEE  2017-04-06 13:32:10
# 3       76457       Permit FINAL_APPROVED by SUPERVISOR  2017-04-06 13:32:28
# 4       76457         Declaration SUBMITTED by EMPLOYEE  2017-04-07 13:38:14
# ...       ...                                       ...                  ...
# 56983   68066         Declaration SUBMITTED by EMPLOYEE  2018-10-15 11:11:15
# 56984   68066    Declaration APPROVED by ADMINISTRATION  2018-10-15 11:18:33
# 56985   68066  Declaration FINAL_APPROVED by SUPERVISOR  2018-10-15 13:49:16
# 56986   68066                           Request Payment  2018-10-15 13:59:03
# 56987   68066                           Payment Handled  2018-10-18 17:31:17
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2      STAFF MEMBER
# 3      STAFF MEMBER
# 4      STAFF MEMBER
# ...             ...
# 56983  STAFF MEMBER
# 56984  STAFF MEMBER
# 56985  STAFF MEMBER
# 56986        SYSTEM
# 56987        SYSTEM
#
# [56988 rows x 4 columns]

# %%
df_test
# Out:
#        NUMPRO                                  CCDOEV               DATAEV  \
# 0       20408            Permit SUBMITTED by EMPLOYEE  2018-08-01 15:29:29
# 1       20408       Permit APPROVED by ADMINISTRATION  2018-08-01 15:29:40
# 2       20408     Permit FINAL_APPROVED by SUPERVISOR  2018-08-02 09:53:38
# 3       20408                              Start trip  2018-10-07 00:00:00
# 4       20408                                End trip  2018-10-10 00:00:00
# ...       ...                                     ...                  ...
# 15158   13232       Declaration SUBMITTED by EMPLOYEE  2018-12-18 15:06:50
# 15159   13232  Declaration REJECTED by ADMINISTRATION  2018-12-18 15:06:57
# 15160   13232        Declaration REJECTED by EMPLOYEE  2018-12-19 14:05:36
# 15161   13232                              Start trip  2019-02-19 00:00:00
# 15162   13232                                End trip  2019-02-24 00:00:00
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2      STAFF MEMBER
# 3      STAFF MEMBER
# 4      STAFF MEMBER
# ...             ...
# 15158  STAFF MEMBER
# 15159  STAFF MEMBER
# 15160  STAFF MEMBER
# 15161  STAFF MEMBER
# 15162  STAFF MEMBER
#
# [15163 rows x 4 columns]

# %%
time_spread(df_train, df_test)

# %%
df_train.to_csv(f'./{dataset}/{subset}/{subset}_prepared/{subset}-TRAIN-CLEAN.csv', index=False)
df_test.to_csv(f'./{dataset}/{subset}/{subset}-TEST-CLEAN.csv', index=False)

# %% [markdown]
# ## PermitLog

# %%
subset = "PermitLog"

# %%
df = pm4py.read_xes('PermitLog.xes')
df
# Out:
# parsing log, completed traces ::   0%|          | 0/7065 [00:00<?, ?it/s]
#                              id  org:resource  \
# 0      rv_travel permit 76455_6  STAFF MEMBER
# 1      rv_travel permit 76455_7  STAFF MEMBER
# 2               st_step 76459_0  STAFF MEMBER
# 3               st_step 76460_0  STAFF MEMBER
# 4               st_step 76461_0  STAFF MEMBER
# ...                         ...           ...
# 86576           st_step 13113_0  STAFF MEMBER
# 86577  rv_travel permit 13108_6  STAFF MEMBER
# 86578           st_step 13112_0  STAFF MEMBER
# 86579           st_step 13114_0  STAFF MEMBER
# 86580  rv_travel permit 13108_7  STAFF MEMBER
#
#                               concept:name            time:timestamp  \
# 0                               Start trip 2016-10-05 00:00:00+00:00
# 1                                 End trip 2016-10-05 00:00:00+00:00
# 2             Permit SUBMITTED by EMPLOYEE 2017-04-06 13:32:10+00:00
# 3      Permit FINAL_APPROVED by SUPERVISOR 2017-04-06 13:32:28+00:00
# 4        Declaration SUBMITTED by EMPLOYEE 2017-04-07 13:38:14+00:00
# ...                                    ...                       ...
# 86576    Permit APPROVED by ADMINISTRATION 2018-12-30 15:11:51+00:00
# 86577                           Start trip 2019-01-02 00:00:00+00:00
# 86578        Permit APPROVED by SUPERVISOR 2019-01-02 09:11:23+00:00
# 86579    Permit FINAL_APPROVED by DIRECTOR 2019-01-07 14:03:29+00:00
# 86580                             End trip 2019-01-16 00:00:00+00:00
#
#              org:role  case:OrganizationalEntity case:ProjectNumber  \
# 0            EMPLOYEE  organizational unit 65458            UNKNOWN
# 1            EMPLOYEE  organizational unit 65458            UNKNOWN
# 2            EMPLOYEE  organizational unit 65458            UNKNOWN
# 3          SUPERVISOR  organizational unit 65458            UNKNOWN
# 4            EMPLOYEE  organizational unit 65458            UNKNOWN
# ...               ...                        ...                ...
# 86576  ADMINISTRATION  organizational unit 65464      project 13110
# 86577        EMPLOYEE  organizational unit 65464      project 13110
# 86578      SUPERVISOR  organizational unit 65464      project 13110
# 86579        DIRECTOR  organizational unit 65464      project 13110
# 86580        EMPLOYEE  organizational unit 65464      project 13110
#
#       case:TaskNumber      case:dec_id_0 case:ActivityNumber  ...  \
# 0             UNKNOWN  declaration 76457      activity 46005  ...
# 1             UNKNOWN  declaration 76457      activity 46005  ...
# 2             UNKNOWN  declaration 76457      activity 46005  ...
# 3             UNKNOWN  declaration 76457      activity 46005  ...
# 4             UNKNOWN  declaration 76457      activity 46005  ...
# ...               ...                ...                 ...  ...
# 86576        task 427                NaN             UNKNOWN  ...
# 86577        task 427                NaN             UNKNOWN  ...
# 86578        task 427                NaN             UNKNOWN  ...
# 86579        task 427                NaN             UNKNOWN  ...
# 86580        task 427                NaN             UNKNOWN  ...
#
#        case:Cost Type_14 case:Cost Type_10 case:Cost Type_11  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 86576                NaN               NaN               NaN
# 86577                NaN               NaN               NaN
# 86578                NaN               NaN               NaN
# 86579                NaN               NaN               NaN
# 86580                NaN               NaN               NaN
#
#        case:Cost Type_12 case:Task_5 case:Task_4 case:Task_9  case:Task_8  \
# 0                    NaN         NaN         NaN         NaN          NaN
# 1                    NaN         NaN         NaN         NaN          NaN
# 2                    NaN         NaN         NaN         NaN          NaN
# 3                    NaN         NaN         NaN         NaN          NaN
# 4                    NaN         NaN         NaN         NaN          NaN
# ...                  ...         ...         ...         ...          ...
# 86576                NaN         NaN         NaN         NaN          NaN
# 86577                NaN         NaN         NaN         NaN          NaN
# 86578                NaN         NaN         NaN         NaN          NaN
# 86579                NaN         NaN         NaN         NaN          NaN
# 86580                NaN         NaN         NaN         NaN          NaN
#
#       case:Task_7  case:Task_6
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 86576         NaN          NaN
# 86577         NaN          NaN
# 86578         NaN          NaN
# 86579         NaN          NaN
# 86580         NaN          NaN
#
# [86581 rows x 173 columns]

# %%
df = df[["case:concept:name", "concept:name", "time:timestamp", "org:resource"]].rename(columns={"case:concept:name": "NUMPRO", "concept:name": "CCDOEV", "time:timestamp": "DATAEV", "org:resource": "NUMGIU"})
df.DATAEV = pd.to_datetime(df.DATAEV).dt.strftime('%Y-%m-%d %H:%M:%S')
cases_ordered = df.groupby("NUMPRO").DATAEV.min().sort_values().keys() # cases numbers ordered by earliest event
df.NUMPRO = pd.Categorical(df.NUMPRO, categories = list(cases_ordered)) # Order cases by earliest event
df = df.sort_values(by = ["NUMPRO","DATAEV"])
df.NUMPRO = df.NUMPRO.str.split().str[-1].astype(int)
df
# Out:
#        NUMPRO                               CCDOEV               DATAEV  \
# 0       76455                           Start trip  2016-10-05 00:00:00
# 1       76455                             End trip  2016-10-05 00:00:00
# 2       76455         Permit SUBMITTED by EMPLOYEE  2017-04-06 13:32:10
# 3       76455  Permit FINAL_APPROVED by SUPERVISOR  2017-04-06 13:32:28
# 4       76455    Declaration SUBMITTED by EMPLOYEE  2017-04-07 13:38:14
# ...       ...                                  ...                  ...
# 86576   13108    Permit APPROVED by ADMINISTRATION  2018-12-30 15:11:51
# 86577   13108                           Start trip  2019-01-02 00:00:00
# 86578   13108        Permit APPROVED by SUPERVISOR  2019-01-02 09:11:23
# 86579   13108    Permit FINAL_APPROVED by DIRECTOR  2019-01-07 14:03:29
# 86580   13108                             End trip  2019-01-16 00:00:00
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2      STAFF MEMBER
# 3      STAFF MEMBER
# 4      STAFF MEMBER
# ...             ...
# 86576  STAFF MEMBER
# 86577  STAFF MEMBER
# 86578  STAFF MEMBER
# 86579  STAFF MEMBER
# 86580  STAFF MEMBER
#
# [86581 rows x 4 columns]

# %%
df_train, df_test = my_train_test_split(df)

# %%
df_train
# Out:
#        NUMPRO                                    CCDOEV               DATAEV  \
# 0       76455                                Start trip  2016-10-05 00:00:00
# 1       76455                                  End trip  2016-10-05 00:00:00
# 2       76455              Permit SUBMITTED by EMPLOYEE  2017-04-06 13:32:10
# 3       76455       Permit FINAL_APPROVED by SUPERVISOR  2017-04-06 13:32:28
# 4       76455         Declaration SUBMITTED by EMPLOYEE  2017-04-07 13:38:14
# ...       ...                                       ...                  ...
# 71817   60144         Declaration SUBMITTED by EMPLOYEE  2018-10-01 13:47:10
# 71818   60144    Declaration APPROVED by ADMINISTRATION  2018-10-01 13:56:55
# 71819   60144  Declaration FINAL_APPROVED by SUPERVISOR  2018-10-03 15:47:18
# 71820   60144                           Request Payment  2018-10-09 07:31:19
# 71821   60144                           Payment Handled  2018-10-11 17:31:07
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2      STAFF MEMBER
# 3      STAFF MEMBER
# 4      STAFF MEMBER
# ...             ...
# 71817  STAFF MEMBER
# 71818  STAFF MEMBER
# 71819  STAFF MEMBER
# 71820        SYSTEM
# 71821        SYSTEM
#
# [71822 rows x 4 columns]

# %%
df_test
# Out:
#        NUMPRO                               CCDOEV               DATAEV  \
# 0       60154         Permit SUBMITTED by EMPLOYEE  2018-09-08 08:22:27
# 1       60154    Permit APPROVED by ADMINISTRATION  2018-09-08 08:23:08
# 2       60154      Permit APPROVED by BUDGET OWNER  2018-09-11 12:53:25
# 3       60154  Permit FINAL_APPROVED by SUPERVISOR  2018-09-17 13:36:15
# 4       60154                           Start trip  2018-10-21 00:00:00
# ...       ...                                  ...                  ...
# 14754   13108    Permit APPROVED by ADMINISTRATION  2018-12-30 15:11:51
# 14755   13108                           Start trip  2019-01-02 00:00:00
# 14756   13108        Permit APPROVED by SUPERVISOR  2019-01-02 09:11:23
# 14757   13108    Permit FINAL_APPROVED by DIRECTOR  2019-01-07 14:03:29
# 14758   13108                             End trip  2019-01-16 00:00:00
#
#              NUMGIU
# 0      STAFF MEMBER
# 1      STAFF MEMBER
# 2      STAFF MEMBER
# 3      STAFF MEMBER
# 4      STAFF MEMBER
# ...             ...
# 14754  STAFF MEMBER
# 14755  STAFF MEMBER
# 14756  STAFF MEMBER
# 14757  STAFF MEMBER
# 14758  STAFF MEMBER
#
# [14759 rows x 4 columns]

# %%
time_spread(df_train, df_test)

# %%
df_train.to_csv(f'./{dataset}/{subset}/{subset}_prepared/{subset}-TRAIN-CLEAN.csv', index=False)
df_test.to_csv(f'./{dataset}/{subset}/{subset}-TEST-CLEAN.csv', index=False)

# %% [markdown]
# ## PrepaidTravelCost

# %%
subset = "PrepaidTravelCost"

# %%
df = pm4py.read_xes('PrepaidTravelCost.xes')
df
# Out:
# parsing log, completed traces ::   0%|          | 0/2099 [00:00<?, ?it/s]
#                                      id  org:resource  \
# 0                       st_step 73555_0  STAFF MEMBER
# 1                       st_step 73554_0  STAFF MEMBER
# 2                       st_step 73558_0  STAFF MEMBER
# 3                       st_step 73559_0  STAFF MEMBER
# 4                       st_step 73557_0  STAFF MEMBER
# ...                                 ...           ...
# 18241                  st_step 186614_0  STAFF MEMBER
# 18242                  st_step 186616_0  STAFF MEMBER
# 18243                  st_step 186615_0  STAFF MEMBER
# 18244  rp_request for payment 186612_15        SYSTEM
# 18245  rp_request for payment 186612_16        SYSTEM
#
#                                            concept:name  \
# 0                          Permit SUBMITTED by EMPLOYEE
# 1                   Permit FINAL_APPROVED by SUPERVISOR
# 2             Request For Payment SUBMITTED by EMPLOYEE
# 3      Request For Payment FINAL_APPROVED by SUPERVISOR
# 4               Request For Payment REJECTED by MISSING
# ...                                                 ...
# 18241         Request For Payment SUBMITTED by EMPLOYEE
# 18242    Request For Payment APPROVED by ADMINISTRATION
# 18243  Request For Payment FINAL_APPROVED by SUPERVISOR
# 18244                                   Request Payment
# 18245                                   Payment Handled
#
#                  time:timestamp        org:role                 case:Rfp_id  \
# 0     2017-01-09 14:48:43+00:00        EMPLOYEE   request for payment 73550
# 1     2017-01-09 14:48:55+00:00      SUPERVISOR   request for payment 73550
# 2     2017-01-12 11:40:27+00:00        EMPLOYEE   request for payment 73550
# 3     2017-01-12 11:41:59+00:00      SUPERVISOR   request for payment 73550
# 4     2017-01-12 11:53:07+00:00         MISSING   request for payment 73550
# ...                         ...             ...                         ...
# 18241 2018-12-30 20:16:15+00:00        EMPLOYEE  request for payment 186612
# 18242 2018-12-30 20:16:25+00:00  ADMINISTRATION  request for payment 186612
# 18243 2019-01-14 15:09:11+00:00      SUPERVISOR  request for payment 186612
# 18244 2019-01-15 07:02:45+00:00       UNDEFINED  request for payment 186612
# 18245 2019-01-17 17:31:44+00:00       UNDEFINED  request for payment 186612
#
#       case:Permit travel permit number   case:Task  case:OrganizationalEntity  \
# 0                              UNKNOWN  task 71977  organizational unit 65463
# 1                              UNKNOWN  task 71977  organizational unit 65463
# 2                              UNKNOWN  task 71977  organizational unit 65463
# 3                              UNKNOWN  task 71977  organizational unit 65463
# 4                              UNKNOWN  task 71977  organizational unit 65463
# ...                                ...         ...                        ...
# 18241                          UNKNOWN     UNKNOWN  organizational unit 65462
# 18242                          UNKNOWN     UNKNOWN  organizational unit 65462
# 18243                          UNKNOWN     UNKNOWN  organizational unit 65462
# 18244                          UNKNOWN     UNKNOWN  organizational unit 65462
# 18245                          UNKNOWN     UNKNOWN  organizational unit 65462
#
#        case:RequestedAmount  ... case:Permit BudgetNumber  \
# 0                854.579838  ...              budget 6198
# 1                854.579838  ...              budget 6198
# 2                854.579838  ...              budget 6198
# 3                854.579838  ...              budget 6198
# 4                854.579838  ...              budget 6198
# ...                     ...  ...                      ...
# 18241             96.739075  ...                  UNKNOWN
# 18242             96.739075  ...                  UNKNOWN
# 18243             96.739075  ...                  UNKNOWN
# 18244             96.739075  ...                  UNKNOWN
# 18245             96.739075  ...                  UNKNOWN
#
#       case:Permit ProjectNumber    case:Project           case:concept:name  \
# 0                       UNKNOWN     project 503   request for payment 73550
# 1                       UNKNOWN     project 503   request for payment 73550
# 2                       UNKNOWN     project 503   request for payment 73550
# 3                       UNKNOWN     project 503   request for payment 73550
# 4                       UNKNOWN     project 503   request for payment 73550
# ...                         ...             ...                         ...
# 18241                   UNKNOWN  project 147531  request for payment 186612
# 18242                   UNKNOWN  project 147531  request for payment 186612
# 18243                   UNKNOWN  project 147531  request for payment 186612
# 18244                   UNKNOWN  project 147531  request for payment 186612
# 18245                   UNKNOWN  project 147531  request for payment 186612
#
#       case:Permit OrganizationalEntity case:Permit RequestedBudget  \
# 0            organizational unit 65455                 1979.272104
# 1            organizational unit 65455                 1979.272104
# 2            organizational unit 65455                 1979.272104
# 3            organizational unit 65455                 1979.272104
# 4            organizational unit 65455                 1979.272104
# ...                                ...                         ...
# 18241                          UNKNOWN                    0.000000
# 18242                          UNKNOWN                    0.000000
# 18243                          UNKNOWN                    0.000000
# 18244                          UNKNOWN                    0.000000
# 18245                          UNKNOWN                    0.000000
#
#       case:Cost Type       case:Permit id  case:Permit ActivityNumber  \
# 0                  0  travel permit 73549                     UNKNOWN
# 1                  0  travel permit 73549                     UNKNOWN
# 2                  0  travel permit 73549                     UNKNOWN
# 3                  0  travel permit 73549                     UNKNOWN
# 4                  0  travel permit 73549                     UNKNOWN
# ...              ...                  ...                         ...
# 18241              0              UNKNOWN                     UNKNOWN
# 18242              0              UNKNOWN                     UNKNOWN
# 18243              0              UNKNOWN                     UNKNOWN
# 18244              0              UNKNOWN                     UNKNOWN
# 18245              0              UNKNOWN                     UNKNOWN
#
#                           case:RfpNumber
# 0       request for payment number 73551
# 1       request for payment number 73551
# 2       request for payment number 73551
# 3       request for payment number 73551
# 4       request for payment number 73551
# ...                                  ...
# 18241  request for payment number 186613
# 18242  request for payment number 186613
# 18243  request for payment number 186613
# 18244  request for payment number 186613
# 18245  request for payment number 186613
#
# [18246 rows x 22 columns]

# %%
df = df[["case:concept:name", "concept:name", "time:timestamp", "org:resource"]].rename(columns={"case:concept:name": "NUMPRO", "concept:name": "CCDOEV", "time:timestamp": "DATAEV", "org:resource": "NUMGIU"})
df.DATAEV = pd.to_datetime(df.DATAEV).dt.strftime('%Y-%m-%d %H:%M:%S')
cases_ordered = df.groupby("NUMPRO").DATAEV.min().sort_values().keys() # cases numbers ordered by earliest event
df.NUMPRO = pd.Categorical(df.NUMPRO, categories = list(cases_ordered)) # Order cases by earliest event
df = df.sort_values(by = ["NUMPRO","DATAEV"])
df.NUMPRO = df.NUMPRO.str.split().str[-1].astype(int)
df
# Out:
#        NUMPRO                                            CCDOEV  \
# 0       73550                      Permit SUBMITTED by EMPLOYEE
# 1       73550               Permit FINAL_APPROVED by SUPERVISOR
# 2       73550         Request For Payment SUBMITTED by EMPLOYEE
# 3       73550  Request For Payment FINAL_APPROVED by SUPERVISOR
# 4       73550           Request For Payment REJECTED by MISSING
# ...       ...                                               ...
# 18241  186612         Request For Payment SUBMITTED by EMPLOYEE
# 18242  186612    Request For Payment APPROVED by ADMINISTRATION
# 18243  186612  Request For Payment FINAL_APPROVED by SUPERVISOR
# 18244  186612                                   Request Payment
# 18245  186612                                   Payment Handled
#
#                     DATAEV        NUMGIU
# 0      2017-01-09 14:48:43  STAFF MEMBER
# 1      2017-01-09 14:48:55  STAFF MEMBER
# 2      2017-01-12 11:40:27  STAFF MEMBER
# 3      2017-01-12 11:41:59  STAFF MEMBER
# 4      2017-01-12 11:53:07  STAFF MEMBER
# ...                    ...           ...
# 18241  2018-12-30 20:16:15  STAFF MEMBER
# 18242  2018-12-30 20:16:25  STAFF MEMBER
# 18243  2019-01-14 15:09:11  STAFF MEMBER
# 18244  2019-01-15 07:02:45        SYSTEM
# 18245  2019-01-17 17:31:44        SYSTEM
#
# [18246 rows x 4 columns]

# %%
df_train, df_test = my_train_test_split(df)

# %%
df_train
# Out:
#        NUMPRO                                            CCDOEV  \
# 0       73550                      Permit SUBMITTED by EMPLOYEE
# 1       73550               Permit FINAL_APPROVED by SUPERVISOR
# 2       73550         Request For Payment SUBMITTED by EMPLOYEE
# 3       73550  Request For Payment FINAL_APPROVED by SUPERVISOR
# 4       73550           Request For Payment REJECTED by MISSING
# ...       ...                                               ...
# 14673   63662         Request For Payment SUBMITTED by EMPLOYEE
# 14674   63662    Request For Payment APPROVED by ADMINISTRATION
# 14675   63662  Request For Payment FINAL_APPROVED by SUPERVISOR
# 14676   63662                                   Request Payment
# 14677   63662                                   Payment Handled
#
#                     DATAEV        NUMGIU
# 0      2017-01-09 14:48:43  STAFF MEMBER
# 1      2017-01-09 14:48:55  STAFF MEMBER
# 2      2017-01-12 11:40:27  STAFF MEMBER
# 3      2017-01-12 11:41:59  STAFF MEMBER
# 4      2017-01-12 11:53:07  STAFF MEMBER
# ...                    ...           ...
# 14673  2018-08-10 11:41:35  STAFF MEMBER
# 14674  2018-08-10 11:42:14  STAFF MEMBER
# 14675  2018-08-10 12:42:06  STAFF MEMBER
# 14676  2018-08-16 07:07:58        SYSTEM
# 14677  2018-08-20 17:31:18        SYSTEM
#
# [14678 rows x 4 columns]

# %%
df_test
# Out:
#       NUMPRO                                            CCDOEV  \
# 0      63680                      Permit SUBMITTED by EMPLOYEE
# 1      63680                 Permit APPROVED by ADMINISTRATION
# 2      63680                   Permit APPROVED by BUDGET OWNER
# 3      63680               Permit FINAL_APPROVED by SUPERVISOR
# 4      63680         Request For Payment SUBMITTED by EMPLOYEE
# ...      ...                                               ...
# 3563  186612         Request For Payment SUBMITTED by EMPLOYEE
# 3564  186612    Request For Payment APPROVED by ADMINISTRATION
# 3565  186612  Request For Payment FINAL_APPROVED by SUPERVISOR
# 3566  186612                                   Request Payment
# 3567  186612                                   Payment Handled
#
#                    DATAEV        NUMGIU
# 0     2018-08-06 14:10:58  STAFF MEMBER
# 1     2018-08-06 14:11:12  STAFF MEMBER
# 2     2018-08-13 09:50:52  STAFF MEMBER
# 3     2018-08-20 05:15:27  STAFF MEMBER
# 4     2018-09-04 14:29:31  STAFF MEMBER
# ...                   ...           ...
# 3563  2018-12-30 20:16:15  STAFF MEMBER
# 3564  2018-12-30 20:16:25  STAFF MEMBER
# 3565  2019-01-14 15:09:11  STAFF MEMBER
# 3566  2019-01-15 07:02:45        SYSTEM
# 3567  2019-01-17 17:31:44        SYSTEM
#
# [3568 rows x 4 columns]

# %%
time_spread(df_train, df_test)

# %%
df_train.to_csv(f'./{dataset}/{subset}/{subset}_prepared/{subset}-TRAIN-CLEAN.csv', index=False)
df_test.to_csv(f'./{dataset}/{subset}/{subset}-TEST-CLEAN.csv', index=False)

# %% [markdown]
# ## RequestForPayment

# %%
subset = "RequestForPayment"

# %%
df = pm4py.read_xes('RequestForPayment.xes')
df
# Out:
# parsing log, completed traces ::   0%|          | 0/6886 [00:00<?, ?it/s]
#                                      id  org:resource  \
# 0                      st_step 148220_0  STAFF MEMBER
# 1                      st_step 148221_0  STAFF MEMBER
# 2                      st_step 148222_0  STAFF MEMBER
# 3                      st_step 148219_0  STAFF MEMBER
# 4                      st_step 148218_0  STAFF MEMBER
# ...                                 ...           ...
# 36791                  st_step 185004_0  STAFF MEMBER
# 36792                  st_step 185003_0  STAFF MEMBER
# 36793                  st_step 185005_0  STAFF MEMBER
# 36794  rp_request for payment 185000_15        SYSTEM
# 36795  rp_request for payment 185000_16        SYSTEM
#
#                                            concept:name  \
# 0             Request For Payment SUBMITTED by EMPLOYEE
# 1      Request For Payment FINAL_APPROVED by SUPERVISOR
# 2               Request For Payment REJECTED by MISSING
# 3             Request For Payment SUBMITTED by EMPLOYEE
# 4          Request For Payment APPROVED by PRE_APPROVER
# ...                                                 ...
# 36791    Request For Payment APPROVED by ADMINISTRATION
# 36792      Request For Payment APPROVED by BUDGET OWNER
# 36793  Request For Payment FINAL_APPROVED by SUPERVISOR
# 36794                                   Request Payment
# 36795                                   Payment Handled
#
#                  time:timestamp        org:role                 case:Rfp_id  \
# 0     2017-01-09 09:17:18+00:00        EMPLOYEE  request for payment 148214
# 1     2017-01-09 09:18:00+00:00      SUPERVISOR  request for payment 148214
# 2     2017-01-10 12:42:32+00:00         MISSING  request for payment 148214
# 3     2017-03-03 09:51:13+00:00        EMPLOYEE  request for payment 148214
# 4     2017-03-03 09:51:42+00:00    PRE_APPROVER  request for payment 148214
# ...                         ...             ...                         ...
# 36791 2018-12-29 12:35:02+00:00  ADMINISTRATION  request for payment 185000
# 36792 2019-01-03 09:27:20+00:00    BUDGET OWNER  request for payment 185000
# 36793 2019-01-08 09:00:39+00:00      SUPERVISOR  request for payment 185000
# 36794 2019-01-08 09:29:14+00:00       UNDEFINED  request for payment 185000
# 36795 2019-01-10 17:31:09+00:00       UNDEFINED  request for payment 185000
#
#          case:Project    case:Task           case:concept:name  \
# 0      project 148216      UNKNOWN  request for payment 148214
# 1      project 148216      UNKNOWN  request for payment 148214
# 2      project 148216      UNKNOWN  request for payment 148214
# 3      project 148216      UNKNOWN  request for payment 148214
# 4      project 148216      UNKNOWN  request for payment 148214
# ...               ...          ...                         ...
# 36791  project 147860  task 152704  request for payment 185000
# 36792  project 147860  task 152704  request for payment 185000
# 36793  project 147860  task 152704  request for payment 185000
# 36794  project 147860  task 152704  request for payment 185000
# 36795  project 147860  task 152704  request for payment 185000
#
#        case:OrganizationalEntity  case:Cost Type  case:RequestedAmount  \
# 0      organizational unit 65463               0             34.336343
# 1      organizational unit 65463               0             34.336343
# 2      organizational unit 65463               0             34.336343
# 3      organizational unit 65463               0             34.336343
# 4      organizational unit 65463               0             34.336343
# ...                          ...             ...                   ...
# 36791  organizational unit 65468               0             15.409660
# 36792  organizational unit 65468               0             15.409660
# 36793  organizational unit 65468               0             15.409660
# 36794  organizational unit 65468               0             15.409660
# 36795  organizational unit 65468               0             15.409660
#
#       case:Activity                     case:RfpNumber
# 0           UNKNOWN  request for payment number 148215
# 1           UNKNOWN  request for payment number 148215
# 2           UNKNOWN  request for payment number 148215
# 3           UNKNOWN  request for payment number 148215
# 4           UNKNOWN  request for payment number 148215
# ...             ...                                ...
# 36791  activity 505  request for payment number 185001
# 36792  activity 505  request for payment number 185001
# 36793  activity 505  request for payment number 185001
# 36794  activity 505  request for payment number 185001
# 36795  activity 505  request for payment number 185001
#
# [36796 rows x 14 columns]

# %%
df = df[["case:concept:name", "concept:name", "time:timestamp", "org:resource"]].rename(columns={"case:concept:name": "NUMPRO", "concept:name": "CCDOEV", "time:timestamp": "DATAEV", "org:resource": "NUMGIU"})
df.DATAEV = pd.to_datetime(df.DATAEV).dt.strftime('%Y-%m-%d %H:%M:%S')
cases_ordered = df.groupby("NUMPRO").DATAEV.min().sort_values().keys() # cases numbers ordered by earliest event
df.NUMPRO = pd.Categorical(df.NUMPRO, categories = list(cases_ordered)) # Order cases by earliest event
df = df.sort_values(by = ["NUMPRO","DATAEV"])
df.NUMPRO = df.NUMPRO.str.split().str[-1].astype(int)
df
# Out:
#        NUMPRO                                            CCDOEV  \
# 0      148214         Request For Payment SUBMITTED by EMPLOYEE
# 1      148214  Request For Payment FINAL_APPROVED by SUPERVISOR
# 2      148214           Request For Payment REJECTED by MISSING
# 3      148214         Request For Payment SUBMITTED by EMPLOYEE
# 4      148214      Request For Payment APPROVED by PRE_APPROVER
# ...       ...                                               ...
# 36791  185000    Request For Payment APPROVED by ADMINISTRATION
# 36792  185000      Request For Payment APPROVED by BUDGET OWNER
# 36793  185000  Request For Payment FINAL_APPROVED by SUPERVISOR
# 36794  185000                                   Request Payment
# 36795  185000                                   Payment Handled
#
#                     DATAEV        NUMGIU
# 0      2017-01-09 09:17:18  STAFF MEMBER
# 1      2017-01-09 09:18:00  STAFF MEMBER
# 2      2017-01-10 12:42:32  STAFF MEMBER
# 3      2017-03-03 09:51:13  STAFF MEMBER
# 4      2017-03-03 09:51:42  STAFF MEMBER
# ...                    ...           ...
# 36791  2018-12-29 12:35:02  STAFF MEMBER
# 36792  2019-01-03 09:27:20  STAFF MEMBER
# 36793  2019-01-08 09:00:39  STAFF MEMBER
# 36794  2019-01-08 09:29:14        SYSTEM
# 36795  2019-01-10 17:31:09        SYSTEM
#
# [36796 rows x 4 columns]

# %%
df_train, df_test = my_train_test_split(df)

# %%
df_train
# Out:
#        NUMPRO                                            CCDOEV  \
# 0      148214         Request For Payment SUBMITTED by EMPLOYEE
# 1      148214  Request For Payment FINAL_APPROVED by SUPERVISOR
# 2      148214           Request For Payment REJECTED by MISSING
# 3      148214         Request For Payment SUBMITTED by EMPLOYEE
# 4      148214      Request For Payment APPROVED by PRE_APPROVER
# ...       ...                                               ...
# 29300  182954                                   Request Payment
# 29301  182954                                   Payment Handled
# 29302  182960         Request For Payment SUBMITTED by EMPLOYEE
# 29303  182960    Request For Payment REJECTED by ADMINISTRATION
# 29304  182960          Request For Payment REJECTED by EMPLOYEE
#
#                     DATAEV        NUMGIU
# 0      2017-01-09 09:17:18  STAFF MEMBER
# 1      2017-01-09 09:18:00  STAFF MEMBER
# 2      2017-01-10 12:42:32  STAFF MEMBER
# 3      2017-03-03 09:51:13  STAFF MEMBER
# 4      2017-03-03 09:51:42  STAFF MEMBER
# ...                    ...           ...
# 29300  2018-10-29 08:19:38        SYSTEM
# 29301  2018-11-01 17:31:17        SYSTEM
# 29302  2018-10-19 10:13:57  STAFF MEMBER
# 29303  2018-10-19 10:57:01  STAFF MEMBER
# 29304  2018-10-25 09:54:55  STAFF MEMBER
#
# [29305 rows x 4 columns]

# %%
df_test
# Out:
#       NUMPRO                                            CCDOEV  \
# 0     179254             Request For Payment SAVED by EMPLOYEE
# 1     176152         Request For Payment SUBMITTED by EMPLOYEE
# 2     176152    Request For Payment APPROVED by ADMINISTRATION
# 3     176152  Request For Payment FINAL_APPROVED by SUPERVISOR
# 4     176152                                   Request Payment
# ...      ...                                               ...
# 7486  185000    Request For Payment APPROVED by ADMINISTRATION
# 7487  185000      Request For Payment APPROVED by BUDGET OWNER
# 7488  185000  Request For Payment FINAL_APPROVED by SUPERVISOR
# 7489  185000                                   Request Payment
# 7490  185000                                   Payment Handled
#
#                    DATAEV        NUMGIU
# 0     2018-10-19 11:05:40  STAFF MEMBER
# 1     2018-10-19 11:23:43  STAFF MEMBER
# 2     2018-10-19 11:23:53  STAFF MEMBER
# 3     2018-10-24 10:12:33  STAFF MEMBER
# 4     2018-10-24 19:57:37        SYSTEM
# ...                   ...           ...
# 7486  2018-12-29 12:35:02  STAFF MEMBER
# 7487  2019-01-03 09:27:20  STAFF MEMBER
# 7488  2019-01-08 09:00:39  STAFF MEMBER
# 7489  2019-01-08 09:29:14        SYSTEM
# 7490  2019-01-10 17:31:09        SYSTEM
#
# [7491 rows x 4 columns]

# %%
time_spread(df_train, df_test)

# %%
df_train.to_csv(f'./{dataset}/{subset}/{subset}_prepared/{subset}-TRAIN-CLEAN.csv', index=False)
df_test.to_csv(f'./{dataset}/{subset}/{subset}-TEST-CLEAN.csv', index=False)
